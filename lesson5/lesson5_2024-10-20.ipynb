# %% [markdown]
# ## 2024-10-20 下午

# %%
print('hello')
# Out:
# hello

# %%
# !pip install psycopg2-binary

# %% [markdown]
# ### 安裝psycopg2 提供 sql 套件
# ![image.png](attachment:image.png)

# %%
import psycopg2

# %%
# !pip install ipykernel

# %%
# !python -m ipykernel install --user --name=sql_py310
# Out:
# Installed kernelspec sql_py310 in C:\Users\sss83\AppData\Roaming\jupyter\kernels\sql_py310

# %%
# 連線到 raspberry 
import psycopg2
connect = psycopg2.connect( host='192.168.0.252',
                            database='mydatabase_a29',
                            user='a29',
                            password='raspberry')
cursor = connect.cursor()
cursor.execute(
"SELECT version();\
"
)
db_version = cursor.fetchone()
print(db_version)
cursor.close()
connect.close()
# Out:
# ('PostgreSQL 15.8 (Debian 15.8-0+deb12u1) on aarch64-unknown-linux-gnu, compiled by gcc (Debian 12.2.0-14) 12.2.0, 64-bit',)

# %%
# 連線到 render 
import psycopg2
connect = psycopg2.connect( host='dpg-cs9su923esus739lqq3g-a.oregon-postgres.render.com',
                            database='remote_render',
                            user='remote_render_user',
                            password='u9ErznaZUhv1OcXi8JXkdCeapEHfceK1')
cursor = connect.cursor()
cursor.execute(
"SELECT version();"
)
db_version = cursor.fetchone()
print(db_version)
cursor.close()
connect.close()
# Out:
# ('PostgreSQL 16.3 (Debian 16.3-1.pgdg120+1) on x86_64-pc-linux-gnu, compiled by gcc (Debian 12.2.0-14) 12.2.0, 64-bit',)

# %% [markdown]
# postgresql://remote_render_user:u9ErznaZUhv1OcXi8JXkdCeapEHfceK1@dpg-cs9su923esus739lqq3g-a.oregon-postgres.render.com/remote_render
#
# postgresql://
# remote_render_user
# :
# u9ErznaZUhv1OcXi8JXkdCeapEHfceK1
# @
# dpg-cs9su923esus739lqq3g-a.oregon-postgres.render.com
# /
# remote_render

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 連線到 render 
import psycopg2
connect = psycopg2.connect( host='dpg-cs9su923esus739lqq3g-a.oregon-postgres.render.com',
                            database='remote_render',
                            user='remote_render_user',
                            password='u9ErznaZUhv1OcXi8JXkdCeapEHfceK1')
cursor = connect.cursor()
cursor.execute(
"SELECT stationName\
FROM train_stations_tw\
GROUP BY stationName;\
"
)
db_version = cursor.fetchone()
print(db_version)
cursor.close()
connect.close()
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# Cell In[12], line 8
#       3 connect = psycopg2.connect( host='dpg-cs9su923esus739lqq3g-a.oregon-postgres.render.com',
#       4                             database='remote_render',
#       5                             user='remote_render_user',
#       6                             password='u9ErznaZUhv1OcXi8JXkdCeapEHfceK1')
#       7 cursor = connect.cursor()
# ----> 8 cursor.execute(
#       9 "SELECT stationName;\
#      10 FROM train_stations_tw;\
#      11 GROUP BY stationName;\
#      12 "
#      13 )
#      14 db_version = cursor.fetchone()
#      15 print(db_version)
#
# SyntaxError: syntax error at or near "FROM"
# LINE 1: SELECT stationName;FROM train_stations_tw;GROUP BY stationNa...
#                            ^

# %%
# 安裝此專案縮需套件
# !pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\sss83\py_class\py_SQL\GitHub\py_sql_class_2024_09_22\lesson5

# %%
# 安裝此專案縮需套件
# !pip install -r ../lesson6/requirements.txt
